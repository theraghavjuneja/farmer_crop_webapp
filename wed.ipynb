# %%
import pandas as pd
df=pd.read_csv("commodities_data.csv")
df
# Out:
#             State    District                   Market              Commodity  \
# 0      Chandigarh  Chandigarh  Chandigarh(Grain/Fruit)                 Grapes
# 1      Chandigarh  Chandigarh  Chandigarh(Grain/Fruit)                 Potato
# 2      Chandigarh  Chandigarh  Chandigarh(Grain/Fruit)                Pumpkin
# 3     Chattisgarh      Kanker                Narharpur    Paddy(Dhan)(Common)
# 4         Gujarat       Anand    Anand(Veg,Yard,Anand)                  Onion
# ...           ...         ...                      ...                    ...
# 2961  West Bengal  Darjeeling      Karsiyang(Matigara)                Cabbage
# 2962  West Bengal  Darjeeling      Karsiyang(Matigara)                   Rice
# 2963  West Bengal  Darjeeling                 Siliguri          Ginger(Green)
# 2964  West Bengal       Malda            English Bazar  Lentil (Masur)(Whole)
# 2965  West Bengal       Malda            English Bazar                   Rice
#
# ...

# %%
df['Arrival_Date']='24/04/2024'

# %%
df
# Out:
#             State    District                   Market              Commodity  \
# 0      Chandigarh  Chandigarh  Chandigarh(Grain/Fruit)                 Grapes
# 1      Chandigarh  Chandigarh  Chandigarh(Grain/Fruit)                 Potato
# 2      Chandigarh  Chandigarh  Chandigarh(Grain/Fruit)                Pumpkin
# 3     Chattisgarh      Kanker                Narharpur    Paddy(Dhan)(Common)
# 4         Gujarat       Anand    Anand(Veg,Yard,Anand)                  Onion
# ...           ...         ...                      ...                    ...
# 2961  West Bengal  Darjeeling      Karsiyang(Matigara)                Cabbage
# 2962  West Bengal  Darjeeling      Karsiyang(Matigara)                   Rice
# 2963  West Bengal  Darjeeling                 Siliguri          Ginger(Green)
# 2964  West Bengal       Malda            English Bazar  Lentil (Masur)(Whole)
# 2965  West Bengal       Malda            English Bazar                   Rice
#
# ...

# %%
df.to_csv('commodities_data.csv',index=False)
